# %%
import pandas as pd

# %%
coutry =['india','china','usa','nepal']
pd.Series(coutry)
# Out:
# 0    india
# 1    china
# 2      usa
# 3    nepal
# dtype: object

# %%
mark=[43,54,45,65,45]
sub=['math','science','hindi','math','science']
pd.Series(mark,index=sub)
# Out:
# math       43
# science    54
# hindi      45
# math       65
# science    45
# dtype: int64

# %%
mark={

      'math':65,
      'english':45,
      'science':35

}
mark_series=pd.Series(mark)

# %%
mark_series
# Out:
# math       65
# english    45
# science    35
# dtype: int64

# %%
mark_series.dtype
# Out:
# dtype('int64')

# %%
mark_series.index
# Out:
# Index(['math', 'english', 'science'], dtype='object')

# %%
mark_series.values
# Out:
# array([65, 45, 35])

# %%
subs=pd.read_csv('/movies.csv')
subs
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
mov=pd.read_csv('/indian movies.csv')
mov
# Out:
#                    Movie Name
# 0                 Dr. Shaitan
# 1                  Nadir Khan
# 2      Apna Sapna Money Money
# 3              Aag Aur Sholay
# 4                     Parivar
# ...                       ...
# 50597          Sulagte Armaan
# 50598                  Aranya
# 50599              Balayogini
# 50600                 Alajadi
# 50601             KA-99 B-333
#
# [50602 rows x 1 columns]

# %%
mov.head(4)
# Out:
#                Movie Name
# 0             Dr. Shaitan
# 1              Nadir Khan
# 2  Apna Sapna Money Money
# 3          Aag Aur Sholay

# %%
mov.tail(4)
# Out:
#         Movie Name
# 50598       Aranya
# 50599   Balayogini
# 50600      Alajadi
# 50601  KA-99 B-333

# %%
mov.size
# Out:
# 50602

# %%
mov.head(4)
# Out:
#                Movie Name
# 0             Dr. Shaitan
# 1              Nadir Khan
# 2  Apna Sapna Money Money
# 3          Aag Aur Sholay

# %%
mov.sample(10)
# Out:
#                            Movie Name
# 659                         Nam Naadu
# 5852                     Ramdhari B.A
# 34643                     Farar Qaidi
# 32696               Slumdog Karodpati
# 30645                   Sugandhavally
# 40839                         Kasauti
# 35285             Rukmavati Ki Haveli
# 10569                          Paalam
# 23587                          Lihaaf
# 20444  Sattathin Thirappu Vizhaa 1989

# %%
dd=pd.read_csv('/content/diabetes.csv')
dd
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dd.Insulin
# Out:
# 0        0
# 1        0
# 2        0
# 3       94
# 4      168
#       ...
# 763    180
# 764      0
# 765    112
# 766      0
# 767      0
# Name: Insulin, Length: 768, dtype: int64

# %%
dd.Glucose
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
dd.BloodPressure
# Out:
# 0      72
# 1      66
# 2      64
# 3      66
# 4      40
#        ..
# 763    76
# 764    70
# 765    72
# 766    60
# 767    70
# Name: BloodPressure, Length: 768, dtype: int64

# %%
dd.mean()
print('1',dd.Glucose.median(),"\n")
print("*---------------------------------------*")
print('2',dd.Glucose.mode(),"\n")
print("*---------------------------------------*")
print('3',dd.Glucose.std(),"\n")
print("*---------------------------------------*")
print('4',dd.Glucose.var(),"\n")
print("*---------------------------------------*")
# Out:
# 1 117.0
#
# *---------------------------------------*
# 2 0     99
# 1    100
# Name: Glucose, dtype: int64
#
# *---------------------------------------*
# 3 31.97261819513622
#
# *---------------------------------------*
# 4 1022.2483142519557
#
# *---------------------------------------*
